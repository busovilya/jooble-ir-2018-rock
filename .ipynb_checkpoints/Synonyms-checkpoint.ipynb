# %%
from flask import Flask, request
import json

app = Flask(__name__)


@app.route('/analysis/synonymus', methods =['POST'])
def detector():
    j = request.json
    synonyms = ['work']#get_synonyms(j['data'])
    new_data = j['data'] + synonyms
    return json.dumps({"status":"ok", "got_data": j["data"], "processed_data":new_data})
    

if __name__ == "__main__":
    app.run(host='0.0.0.0', port=13539)
# Out:
#  * Running on http://0.0.0.0:13539/ (Press CTRL+C to quit)
# 127.0.0.1 - - [08/Nov/2018 16:02:26] "POST /analysis/synonymus HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Nov/2018 17:03:48] "POST /analysis/synonymus HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Nov/2018 17:04:40] "POST /analysis/synonymus HTTP/1.1" 200 -
